# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Settings

# %%
pd.set_option("display.max_columns", None)
sns.set_theme(style="whitegrid")

# %% [markdown]
# Load data

# %%
df = pd.read_csv("../data/processed_traits/1_civ5_leaders.csv")

id_cols = ["leader_name", "leader_type"]
 
diplo_traits = [
    "VictoryCompetitiveness", "WonderCompetitiveness", "MinorCivCompetitiveness",
    "Boldness", "DiploBalance", "WarmongerHate", "DenounceWillingness",
    "DoFWillingness", "Loyalty", "Neediness", "Forgiveness", "Chattiness", "Meanness"
]
 
major_approaches = [
    "MAJOR_WAR", "MAJOR_HOSTILE", "MAJOR_DECEPTIVE", "MAJOR_GUARDED",
    "MAJOR_AFRAID", "MAJOR_FRIENDLY", "MAJOR_NEUTRAL"
]
 
minor_approaches = [
    "MINOR_IGNORE", "MINOR_FRIENDLY", "MINOR_PROTECTIVE",
    "MINOR_CONQUEST", "MINOR_BULLY"
]
 
flavors = [c for c in df.columns if c not in id_cols + diplo_traits + major_approaches + minor_approaches]
 
print(f"Dataset: {df.shape[0]} leaders x {df.shape[1]} variables")
# Out:
# Dataset: 43 leaders x 65 variables

# %% [markdown]
# Feature engineering

# %%
features = pd.DataFrame()
 
# Identity
features["leader_name"] = df["leader_name"]
 
# Diplomatic traits (kept as-is)
for col in ["WarmongerHate", "WonderCompetitiveness",
            "VictoryCompetitiveness", "Loyalty", "MinorCivCompetitiveness"]:
    features[col] = df[col]
 
# Warrior composite
features["warrior"] = (df["Boldness"] + df["MAJOR_WAR"] + df["MAJOR_HOSTILE"] +
                       df["OFFENSE"] + df["MILITARY_TRAINING"]) / 5
 
# Major approaches
features["friendliness"]  = (df["MAJOR_AFRAID"] + df["MAJOR_FRIENDLY"]) / 2
features["deceptiveness"] = df["MAJOR_DECEPTIVE"]
 
# Minor approaches
features["city_state_stance"] = (df["MINOR_CONQUEST"] + df["MINOR_BULLY"] -
                                  df["MINOR_FRIENDLY"] - df["MINOR_PROTECTIVE"]) / 4
features["minor_ignore"]      = df["MINOR_IGNORE"]
 
# Flavors
features["naval"]     = (df["NAVAL"] + df["NAVAL_RECON"] + df["NAVAL_GROWTH"] +
                         df["NAVAL_TILE_IMPROVEMENT"] + df["WATER_CONNECTION"]) / 5
features["defense"]   = (df["DEFENSE"] + df["CITY_DEFENSE"]) / 2
features["science"]   = (df["SCIENCE"] + df["SPACESHIP"]) / 2
features["EXPANSION"] = df["EXPANSION"]
features["GROWTH"]    = df["GROWTH"]
features["WONDER"]    = df["WONDER"]
features["CULTURE"]   = df["CULTURE"]
features["RELIGION"]  = df["RELIGION"]
features["DIPLOMACY"] = df["DIPLOMACY"]
 
print(f"Feature matrix: {features.shape[0]} leaders x {features.shape[1] - 1} features")
features.head()
# Out:
# Feature matrix: 43 leaders x 19 features
#      leader_name  WarmongerHate  WonderCompetitiveness  \
# 0  AhmadalMansur              5                      4
# 1      Alexander              2                      7
# 2   Ashurbanipal              4                      5
# 3          Askia              4                      8
# 4         Attila              3                      3
#
#    VictoryCompetitiveness  Loyalty  MinorCivCompetitiveness  warrior  \
# 0                       5        6                        5      4.6
# 1                       8        4                        3      6.8
# 2                       5        5                        3      7.0
# 3                       5        6                        4      6.8
# 4                       7        4                        3      7.6
#
#    friendliness  deceptiveness  city_state_stance  minor_ignore  naval  \
# 0           6.5              5              -1.00             4    5.0
# ...

# %% [markdown]
# Centering

# %%
# Mean-centering
#
# Rationale: this project is purely comparative — what matters is how each leader
# deviates from the average, not their absolute values. Centering removes the
# arbitrary absolute offset of each feature while preserving all relative
# differences between leaders. We re-anchor to 5 (the midpoint of the 0–10 scale)
# so that the heatmap remains visually intuitive (5 = average, >5 = above average).
#
# We deliberately do NOT normalize (i.e. divide by std), because features share
# the same underlying scale and normalizing would artificially inflate low-variance
# features, treating a small difference on a near-uniform feature as equivalent to
# a large difference on a truly discriminating one.

feature_cols = [c for c in features.columns if c != "leader_name"]
 
# Save raw means for reference
feature_means = features[feature_cols].mean()
print("Feature means before centering:")
print(feature_means.round(2))
 
# Center each feature: subtract its mean, re-anchor to 5
features_centered = features.copy()
for col in feature_cols:
    features_centered[col] = features[col] - feature_means[col] + 5
 
print("\nFeature means after centering (should all be 5.0):")
print(features_centered[feature_cols].mean().round(2))
 
print("\nFeature std after centering (unchanged vs raw):")
raw_std      = features[feature_cols].std().round(3)
centered_std = features_centered[feature_cols].std().round(3)
comparison   = pd.DataFrame({"raw_std": raw_std, "centered_std": centered_std})
print(comparison)
# Out:
# Feature means before centering:
# WarmongerHate              5.12
# WonderCompetitiveness      5.09
# VictoryCompetitiveness     5.26
# Loyalty                    5.47
# MinorCivCompetitiveness    5.05
# warrior                    5.22
# friendliness               5.20
# deceptiveness              5.14
# city_state_stance         -0.37
# minor_ignore               4.40
# naval                      5.02
# defense                    5.66
# science                    5.76
# EXPANSION                  6.26
# GROWTH                     5.12
# WONDER                     5.14
# CULTURE                    5.86
# RELIGION                   5.65
# DIPLOMACY                  5.53
# dtype: float64
#
# Feature means after centering (should all be 5.0):
# WarmongerHate              5.0
# WonderCompetitiveness      5.0
# VictoryCompetitiveness     5.0
# Loyalty                    5.0
# MinorCivCompetitiveness    5.0
# warrior                    5.0
# friendliness               5.0
# ...

# %% [markdown]
# Save

# %%
features_centered.to_csv("../data/processed_traits/3_civ5_features.csv", index=False)
print("Feature matrix (mean-centered) saved!")
# Out:
# Feature matrix (mean-centered) saved!

# %% [markdown]
# Cross-correlation matrix

# %%
# Note: centering does not affect correlations (Pearson r is invariant to
# additive shifts), so this plot is identical to the pre-centering version.
# It is kept here for completeness and notebook self-containedness.

feature_cols = [c for c in features_centered.columns if c != "leader_name"]
 
corr = features_centered[feature_cols].corr()
 
plt.figure(figsize=(16, 14))
sns.heatmap(corr, cmap="coolwarm", center=0, vmin=-1, vmax=1,
            annot=True, fmt=".2f", annot_kws={"size": 7},
            square=True)
plt.title("Cross-correlation matrix — 19 features (mean-centered)", fontsize=14)
plt.tight_layout()
plt.savefig("../figures/3_cross_correlation_selectedfeatures.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# Residual high-correlation pairs

# %%
pairs = []
for i in range(len(corr.columns)):
    for j in range(i+1, len(corr.columns)):
        r = corr.iloc[i, j]
        if abs(r) > 0.4:
            pairs.append({
                "feature_1": corr.columns[i],
                "feature_2": corr.columns[j],
                "correlation": round(r, 2)
            })
 
pairs_df = pd.DataFrame(pairs).sort_values("correlation", key=abs, ascending=False)
print(pairs_df.to_string(index=False))
# Out:
#              feature_1              feature_2  correlation
#                warrior                defense        -0.73
#                warrior           friendliness        -0.72
#                warrior      city_state_stance         0.63
#          WarmongerHate                warrior        -0.60
#          WarmongerHate VictoryCompetitiveness        -0.59
#                Loyalty          deceptiveness        -0.57
#              EXPANSION                 GROWTH        -0.56
#          WarmongerHate                defense         0.56
#      city_state_stance                defense        -0.55
#           friendliness      city_state_stance        -0.54
# VictoryCompetitiveness                warrior         0.53
#           friendliness                defense         0.51
#                warrior              EXPANSION         0.50
#          WarmongerHate      city_state_stance        -0.49
#      city_state_stance              DIPLOMACY        -0.46
# ...
