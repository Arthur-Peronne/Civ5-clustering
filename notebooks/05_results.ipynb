# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Settings

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 200)
sns.set_theme(style="whitegrid")

# %% [markdown]
# Load data

# %%
features = pd.read_csv("../data/processed_traits/3_civ5_features.csv")
clusters = pd.read_csv("../data/processed_traits/4_civ5_clusters.csv")
features = features.merge(clusters, on="leader_name")

# %% [markdown]
# Constants

# %%
CLUSTER_LABELS = {
    0: "Religious pacifists",
    1: "Aggressive conquerors",
    2: "Unreliable friends",
    3: "Wonder builders",
    4: "Naval expansionists"
}
CLUSTER_COLORS = ["#2ecc71", "#e74c3c", "#e67e22", "#3498db", "#9b59b6"]

FEATURE_NAMES = {
    "warrior": "Military focus",
    "WarmongerHate": "Pacifism",
    "WonderCompetitiveness": "Wonder building",
    "VictoryCompetitiveness": "Victory drive",
    "Loyalty": "Loyalty",
    "MinorCivCompetitiveness": "City-state competition",
    "friendliness": "Friendliness",
    "deceptiveness": "Deceptiveness",
    "city_state_benefactor": "City-state benefactor",
    "minor_ignore": "City-state indifference",
    "naval": "Naval focus",
    "defense": "Defensiveness",
    "science": "Science focus",
    "EXPANSION": "Expansion drive",
    "GROWTH": "City growth",
    "WONDER": "Wonder priority",
    "CULTURE": "Cultural focus",
    "RELIGION": "Religious focus",
    "DIPLOMACY": "Diplomacy focus"
}

RADAR_FEATURES = {
    "Naval focus":        "naval",
    "Military focus":     "warrior",
    "Expansion drive":    "EXPANSION",
    "Victory drive":      "VictoryCompetitiveness",
    "Deceptiveness":      "deceptiveness",
    "City-state competition": "MinorCivCompetitiveness",
    "Science focus":      "science",
    "Wonder priority":    "WONDER",
    "Wonder building":    "WonderCompetitiveness",
    "City growth":        "GROWTH",
    "Defensiveness":      "defense",
    "Friendliness":       "friendliness",
    "City-state benefactor": "city_state_benefactor" ,
    "Pacifism":           "WarmongerHate",
    "Cultural focus":     "CULTURE",
    "Religious focus":    "RELIGION",
    "City-state indifference": "minor_ignore",
    "Loyalty":            "Loyalty",
    "Diplomacy focus":    "DIPLOMACY",
}

features["cluster_name"] = features["cluster"].map(CLUSTER_LABELS)

# %% [markdown]
# Summary table

# %%
feature_cols = [c for c in features.columns
                if c not in ["leader_name", "cluster", "cluster_name", "city_state_stance"]
                and features[c].dtype in ["float64", "int64"]]

def rename_features(feature_str):
    return ", ".join([FEATURE_NAMES.get(f.strip(), f.strip())
                      for f in feature_str.split(",")])

rows = []
for _, row in features.iterrows():
    values = row[feature_cols].astype(float)
    top3 = values.nlargest(3).index.tolist()
    bot3 = values.nsmallest(3).index.tolist()
    rows.append({
        "leader": row["leader_name"],
        "cluster": row["cluster_name"],
        "top features": rename_features(", ".join(top3)),
        "low features": rename_features(", ".join(bot3))
    })

summary = pd.DataFrame(rows).sort_values(["cluster", "leader"])

for cluster_name in sorted(summary["cluster"].unique()):
    print(f"\n{'='*60}")
    print(f"{cluster_name}")
    print(f"{'='*60}")
    sub = summary[summary["cluster"] == cluster_name][["leader", "top features", "low features"]]
    print(sub.to_string(index=False))
# Out:
# ...
# Aggressive conquerors
# ...
#       leader                                             top features                                           low features
#    Alexander          Diplomacy focus, Victory drive, Wonder building              Pacifism, City-state competition, Loyalty
# Ashurbanipal               Military focus, Science focus, Naval focus City-state competition, Defensiveness, Religious focus
#        Askia         Wonder building, Military focus, Religious focus  Deceptiveness, Wonder priority, City-state benefactor
#       Attila             Deceptiveness, Military focus, Victory drive     City-state benefactor, Friendliness, Defensiveness
#     Boudicca Religious focus, City-state indifference, Cultural focus         Friendliness, Expansion drive, Wonder priority
#  GenghisKhan           Victory drive, Military focus, Expansion drive        Diplomacy focus, Deceptiveness, Wonder priority
# ...

# %% [markdown]
# Top/bottom leaders par feature

# %%
n = 3

for col, label in FEATURE_NAMES.items():
    if col not in features.columns:
        continue
    top = features.nlargest(n, col)[["leader_name", col, "cluster_name"]]
    bot = features.nsmallest(n, col)[["leader_name", col, "cluster_name"]]

    top = top.rename(columns={"leader_name": "Leader", col: label, "cluster_name": "Cluster"})
    bot = bot.rename(columns={"leader_name": "Leader", col: label, "cluster_name": "Cluster"})

    print(f"\n{'='*55}")
    print(f"{label}")
    print(f"{'='*55}")
    print(f"  Top {n}:")
    print(top.to_string(index=False))
    print(f"  Bottom {n}:")
    print(bot.to_string(index=False))
# Out:
# ...
# Military focus
# ...
#   Top 3:
#    Leader  Military focus               Cluster
#    Attila        7.376744 Aggressive conquerors
#     Shaka        7.176744 Aggressive conquerors
# Montezuma        6.976744 Aggressive conquerors
#   Bottom 3:
#   Leader  Military focus             Cluster
#   Gandhi        2.776744 Religious pacifists
# Hiawatha        2.976744 Religious pacifists
#   Darius        3.176744  Unreliable friends
#
# ...
# Pacifism
# ...
#   Top 3:
#       Leader  Pacifism             Cluster
# Ramkhamhaeng  7.883721 Religious pacifists
#     Selassie  7.883721 Religious pacifists
#      Casimir  6.883721     Wonder builders
#   Bottom 3:
#    Leader  Pacifism               Cluster
# Montezuma  0.883721 Aggressive conquerors
# Alexander  1.883721 Aggressive conquerors
#    Attila  2.883721 Aggressive conquerors
#
# ...
# Wonder building
# ...
#   Top 3:
#         Leader  Wonder building               Cluster
#       Ramesses         8.906977       Wonder builders
# ...

# %% [markdown]
# Radar chart

# %%
labels = list(RADAR_FEATURES.keys())
cols   = list(RADAR_FEATURES.values())
N      = len(labels)

cluster_profiles = (features
                    .drop(columns=["leader_name", "cluster_name"])
                    .groupby("cluster")
                    .mean(numeric_only=True)[cols])

y_min = cluster_profiles.min().min() 
y_max = cluster_profiles.max().max()

angles = np.linspace(0, 2 * np.pi, N, endpoint=False).tolist()
angles += angles[:1]

fig, axes = plt.subplots(2, 3, figsize=(18, 12), subplot_kw=dict(polar=True))
axes = axes.flatten()

for idx, (cluster_id, label) in enumerate(CLUSTER_LABELS.items()):
    ax = axes[idx]
    values = cluster_profiles.loc[cluster_id, cols].tolist()
    values += values[:1]

    ax.plot(angles, values, color=CLUSTER_COLORS[cluster_id], linewidth=2)
    ax.fill(angles, values, color=CLUSTER_COLORS[cluster_id], alpha=0.25)
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(labels, size=8)
    ax.set_ylim(y_min, y_max)
    ax.set_yticks(np.arange(round(y_min), round(y_max) + 1, 1))
    ax.set_title(label, size=12, fontweight="bold", pad=15)
    ax.grid(True)

axes[-1].set_visible(False)
fig.suptitle("Civ 5 leader clusters — feature profiles (scaled to cluster min/max)",
             fontsize=15, y=1.02)
plt.tight_layout()
plt.savefig("../figures/5_radar_clusters.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
# Radar chart Commentary 
#
# Religious pacifists (Gandhi, HarunAlRashid, Hiawatha, Maria, Pacal, Pocatello, Ramkhamhaeng, Selassie)
# 
# Pacifists, nice to city-stats, friendly, they are mostly religion and culture.
# On the opposite, they ignore the naval part of the game and are un-competitive for the victory.
# 
# Aggressive conquerors (Alexander, Ashurbanipal, Askia, Attila, Boudicca, GenghisKhan, Montezuma, Napoleon, OdaNobunaga, Shaka)
# 
# They rely on their military to expand their border fast and push their advantage to win the game.
# That is basically all they are interested in.
# As a consequency, they score very low in terms of friendliness, pacifism, and are a menace to city-states.
# 
# Unreliable friends (AhmadalMansur, Darius, EnricoDandolo, MariaI, Pedro, Sejong, Theodora)
# 
# What defines this group is their very high friendliness, coupled with un-coopérative traits: deceptiveness and  
# competition toward city-states. These leaders are basically quite balanced in their game, and are friendly 
# until pissed.
# 
# Wonder builders (Augustus, Bismark, Casimir, Catherine, Gustavus, Nebuchadnezzar, Pachacuti, Ramesses, Washington, WuZetian)
# 
# The wonder builders focus on one aspect of the game: the wonders. They prioritize science to lead the technological race
# and be the first to be able to build the seeked wonders. 
# While many wonders tend to strenghen the culture and the religious pressure of the civilization, the leaders of this group do not 
# particularly focus on these aspect of the game and rather use their science and wonders to play a balanced game.
# 
# Naval expansionnists (Dido, Elizabeth, GajahMada, Harald, Isabella, Kamehameha, Suleiman, William)
# 
# These leaders all lead naval-oriented civilization (with unique building or units related to sea) and therefore strongly
# focus on their naval game -> exploration, fishing and naval trade routes.
# This investment on the naval aspect of the game makes them ignore wonders and their city growth.

# %% [markdown]
# Heatmap

# %%
col_order   = list(RADAR_FEATURES.values())
label_order = list(RADAR_FEATURES.keys())

cluster_profiles = (features
                    .drop(columns=["leader_name", "cluster_name"])
                    .groupby("cluster")
                    .mean(numeric_only=True)
                    .round(2))

cluster_profiles_readable = (cluster_profiles[col_order]
                              .rename(columns=dict(zip(col_order, label_order)),
                                      index=CLUSTER_LABELS))

plt.figure(figsize=(14, 5))
sns.heatmap(cluster_profiles_readable,
            annot=True, fmt=".1f",
            cmap="RdYlGn",
            center=5,
            vmin=3, vmax=8,
            linewidths=0.5,
            annot_kws={"size": 9})
plt.title("Civ 5 leader clusters — mean feature values", fontsize=13)
plt.xticks(rotation=45, ha="right", fontsize=9)
plt.yticks(rotation=0, fontsize=9)
plt.tight_layout()
plt.savefig("../figures/5_heatmap_clusters.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
# Clustering conclusions
# 
# This clustering looks positive on several points:
#   - balancer and well-separated clusters
#   - meaningful clusters in terms of game mechanics/strategies
# 
# However the grouping of some leaders together (William the friendly pacifist and Suleiman the naval conqueror), or the place
# of individual leaders on surprising clusters (Sejong the scientist outside of the wonder builders, Theodora the religious not in the 
# corresponding clusters) raises interrogations. Notably, if their distinctive trait weigths enough in the clustering from almost 
# 20 features.
# 
# The leader traits mix indeed some diplomatic (friendly, warmonger, etc.) and strategic (scientific, religious) traits, making the 
# results of the clustering intersting to have a global archetype but harder to interpret. It also questions if the weights of the 
# features (the composite features are weighted according to the number of features grouped in this composite) are justified or not: 
# currently, the naval (coefficient 5) and city-state stance (coefficient 4) have a huge weight in the clustering, that might outweight 
# their actual importance in the game compared to other features (science, culture, etc. only coefficient 1). 
# However some subjective choice already had to be made during the feature selection and creation, and I thought further tweaking of 
# the feature coefficients would bring to much subjectivity to the clustering, and raising the risk to end up in a clustering in line 
# with my preconceptions.
