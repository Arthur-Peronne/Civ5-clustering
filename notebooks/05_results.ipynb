# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Settings

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 200)
sns.set_theme(style="whitegrid")

# %% [markdown]
# Load data

# %%
features = pd.read_csv("../data/civ5_features.csv")
clusters = pd.read_csv("../data/civ5_clusters.csv")
features = features.merge(clusters, on="leader_name")

# %% [markdown]
# Constants

# %%
CLUSTER_LABELS = {
    0: "Balanced diplomats",
    1: "Scientific conquerors",
    2: "Aggressive warmongers",
    3: "Cultural pacifists",
    4: "Wonder builders"
}
CLUSTER_COLORS = ["#2ecc71", "#e74c3c", "#e67e22", "#3498db", "#9b59b6"]

FEATURE_NAMES = {
    "warrior": "Aggressiveness",
    "WarmongerHate": "Pacifism",
    "WonderCompetitiveness": "Wonder building",
    "VictoryCompetitiveness": "Victory drive",
    "Loyalty": "Loyalty",
    "MinorCivCompetitiveness": "City-state competition",
    "friendliness": "Friendliness",
    "deceptiveness": "Deceptiveness",
    "minor_ignore": "City-state indifference",
    "naval": "Naval focus",
    "defense": "Defensiveness",
    "science": "Science focus",
    "EXPANSION": "Expansion drive",
    "GROWTH": "City growth",
    "WONDER": "Wonder priority",
    "CULTURE": "Cultural focus",
    "RELIGION": "Religious focus",
    "DIPLOMACY": "Diplomacy focus"
}

RADAR_FEATURES = {
    "Naval focus":        "naval",
    "Aggressiveness":     "warrior",
    "Victory drive":      "VictoryCompetitiveness",
    "Expansion drive":    "EXPANSION",
    "Deceptiveness":      "deceptiveness",
    "Science focus":      "science",
    "Wonder priority":    "WONDER",
    "Defensiveness":      "defense",
    "Cultural focus":     "CULTURE",
    "City growth":        "GROWTH",
    "Religious focus":    "RELIGION",
    "Friendliness":       "friendliness",
    "Pacifism":           "WarmongerHate",
    "Loyalty":            "Loyalty",
    "Diplomacy focus":    "DIPLOMACY",
}

features["cluster_name"] = features["cluster"].map(CLUSTER_LABELS)

# %% [markdown]
# Summary table

# %%
feature_cols = [c for c in features.columns
                if c not in ["leader_name", "cluster", "cluster_name", "city_state_stance"]
                and features[c].dtype in ["float64", "int64"]]

def rename_features(feature_str):
    return ", ".join([FEATURE_NAMES.get(f.strip(), f.strip())
                      for f in feature_str.split(",")])

rows = []
for _, row in features.iterrows():
    values = row[feature_cols].astype(float)
    top3 = values.nlargest(3).index.tolist()
    bot3 = values.nsmallest(3).index.tolist()
    rows.append({
        "leader": row["leader_name"],
        "cluster": row["cluster_name"],
        "top features": rename_features(", ".join(top3)),
        "low features": rename_features(", ".join(bot3))
    })

summary = pd.DataFrame(rows).sort_values(["cluster", "leader"])

for cluster_name in sorted(summary["cluster"].unique()):
    print(f"\n{'='*60}")
    print(f"{cluster_name}")
    print(f"{'='*60}")
    sub = summary[summary["cluster"] == cluster_name][["leader", "top features", "low features"]]
    print(sub.to_string(index=False))
# Out:
# ============================================================
# Aggressive warmongers
# ============================================================
#       leader                                             top features                                           low features
# Ashurbanipal               Aggressiveness, Science focus, Naval focus City-state competition, Defensiveness, Religious focus
#        Askia         Wonder building, Aggressiveness, Religious focus        Deceptiveness, Wonder priority, Expansion drive
#       Attila             Deceptiveness, Aggressiveness, Victory drive                  Friendliness, Defensiveness, Pacifism
#     Boudicca Religious focus, City-state indifference, Cultural focus         Friendliness, Expansion drive, Wonder priority
#         Dido                Deceptiveness, Naval focus, Victory drive              Wonder priority, Cultural focus, Pacifism
#    GajahMada            Naval focus, Expansion drive, Religious focus                   Loyalty, Science focus, Friendliness
#  GenghisKhan           Victory drive, Aggressiveness, Expansion drive        Diplomacy focus, Deceptiveness, Wonder priority
#       Harald            Naval focus, City-state indifference, Loyalty        Victory drive, Wonder priority, Wonder building
#     Isabella    Religious focus, Naval focus, City-state indifference          Science focus, Defensiveness, Wonder building
#    Montezuma           Aggressiveness, Deceptiveness, Expansion drive               Pacifism, Wonder building, Defensiveness
#        Shaka                  Expansion drive, Victory drive, Loyalty            Friendliness, Deceptiveness, Cultural focus
#
# ============================================================
# Balanced diplomats
# ============================================================
#     leader                                       top features                                             low features
#    Casimir                 Pacifism, Loyalty, Religious focus      Deceptiveness, City-state indifference, City growth
#  Elizabeth      City-state competition, Naval focus, Pacifism               City growth, Friendliness, Religious focus
#   Gustavus           Diplomacy focus, Aggressiveness, Loyalty          Expansion drive, Deceptiveness, Religious focus
#   Hiawatha          Expansion drive, Loyalty, Religious focus       Victory drive, City growth, City-state competition
# Kamehameha             Naval focus, Pacifism, Expansion drive              Victory drive, Wonder priority, City growth
#      Maria  City-state competition, Diplomacy focus, Pacifism      Deceptiveness, Naval focus, City-state indifference
#     MariaI  Friendliness, Naval focus, City-state competition City-state indifference, Aggressiveness, Wonder priority
#  Pocatello        City growth, Defensiveness, Expansion drive               Deceptiveness, Naval focus, Cultural focus
# Washington Pacifism, City-state indifference, Diplomacy focus            City growth, Wonder building, Religious focus
#    William       Naval focus, Loyalty, City-state competition               City growth, Aggressiveness, Deceptiveness
#
# ============================================================
# Cultural pacifists
# ============================================================
#       leader                                   top features                                        low features
#       Gandhi   City growth, Religious focus, Cultural focus      Victory drive, Expansion drive, Aggressiveness
# Ramkhamhaeng      Pacifism, Diplomacy focus, Cultural focus Victory drive, Naval focus, City-state indifference
#     Selassie Pacifism, City growth, City-state indifference         Victory drive, Expansion drive, Naval focus
#
# ============================================================
# Scientific conquerors
# ============================================================
#      leader                                           top features                                  low features
#   Alexander        Diplomacy focus, Victory drive, Wonder building     Pacifism, City-state competition, Loyalty
#    Augustus City-state competition, Victory drive, Expansion drive            Religious focus, Loyalty, Pacifism
#     Bismark   City-state competition, Deceptiveness, Victory drive Religious focus, Naval focus, Wonder priority
#   Catherine Science focus, City-state competition, Wonder building     City growth, Naval focus, Diplomacy focus
#    Napoleon  Victory drive, Cultural focus, City-state competition            Religious focus, Loyalty, Pacifism
# OdaNobunaga         Aggressiveness, Victory drive, Expansion drive        Loyalty, Friendliness, Religious focus
#    Suleiman            Naval focus, Deceptiveness, Expansion drive          Defensiveness, Pacifism, City growth
#
# ============================================================
# Wonder builders
# ============================================================
#         leader                                              top features                                            low features
#  AhmadalMansur                 Friendliness, Cultural focus, City growth       Expansion drive, Wonder priority, Wonder building
#         Darius                      Victory drive, Loyalty, Friendliness        Aggressiveness, Expansion drive, Wonder building
#  EnricoDandolo    City-state competition, Deceptiveness, Diplomacy focus               Expansion drive, Loyalty, Wonder building
#  HarunAlRashid           Religious focus, Wonder building, Science focus City-state indifference, Victory drive, Expansion drive
# Nebuchadnezzar           Wonder building, Wonder priority, Defensiveness       Expansion drive, Loyalty, City-state indifference
#          Pacal City-state indifference, Religious focus, Wonder building    Expansion drive, Naval focus, City-state competition
#      Pachacuti           Wonder building, Wonder priority, Deceptiveness      City-state competition, Naval focus, Science focus
#          Pedro                        City growth, Friendliness, Loyalty          Aggressiveness, Science focus, Expansion drive
#       Ramesses         Wonder priority, Wonder building, Religious focus                 Loyalty, Victory drive, Expansion drive
#         Sejong           Science focus, City-state indifference, Loyalty        Diplomacy focus, Aggressiveness, Expansion drive
#       Theodora               Defensiveness, Wonder building, City growth       Expansion drive, Loyalty, City-state indifference
#       WuZetian        City growth, Science focus, City-state competition                 Diplomacy focus, Loyalty, Victory drive

# %% [markdown]
# Top/bottom leaders par feature

# %%
n = 3

for col, label in FEATURE_NAMES.items():
    if col not in features.columns:
        continue
    top = features.nlargest(n, col)[["leader_name", col, "cluster_name"]]
    bot = features.nsmallest(n, col)[["leader_name", col, "cluster_name"]]

    top = top.rename(columns={"leader_name": "Leader", col: label, "cluster_name": "Cluster"})
    bot = bot.rename(columns={"leader_name": "Leader", col: label, "cluster_name": "Cluster"})

    print(f"\n{'='*55}")
    print(f"{label}")
    print(f"{'='*55}")
    print(f"  Top {n}:")
    print(top.to_string(index=False))
    print(f"  Bottom {n}:")
    print(bot.to_string(index=False))
# Out:
# =======================================================
# Aggressiveness
# =======================================================
#   Top 3:
#    Leader  Aggressiveness               Cluster
#    Attila        7.376744 Aggressive warmongers
#     Shaka        7.176744 Aggressive warmongers
# Montezuma        6.976744 Aggressive warmongers
#   Bottom 3:
#   Leader  Aggressiveness            Cluster
#   Gandhi        2.776744 Cultural pacifists
# Hiawatha        2.976744 Balanced diplomats
#   Darius        3.176744    Wonder builders
#
# =======================================================
# Pacifism
# =======================================================
#   Top 3:
#       Leader  Pacifism            Cluster
# Ramkhamhaeng  7.883721 Cultural pacifists
#     Selassie  7.883721 Cultural pacifists
#      Casimir  6.883721 Balanced diplomats
#   Bottom 3:
#    Leader  Pacifism               Cluster
# Montezuma  0.883721 Aggressive warmongers
# Alexander  1.883721 Scientific conquerors
#    Attila  2.883721 Aggressive warmongers
#
# =======================================================
# Wonder building
# =======================================================
#   Top 3:
#         Leader  Wonder building               Cluster
#       Ramesses         8.906977       Wonder builders
#          Askia         7.906977 Aggressive warmongers
# Nebuchadnezzar         7.906977       Wonder builders
#   Bottom 3:
#        Leader  Wonder building               Cluster
#     Montezuma         1.906977 Aggressive warmongers
#        Attila         2.906977 Aggressive warmongers
# EnricoDandolo         2.906977       Wonder builders
#
# =======================================================
# Victory drive
# =======================================================
#   Top 3:
#      Leader  Victory drive               Cluster
#   Alexander       7.744186 Scientific conquerors
# GenghisKhan       7.744186 Aggressive warmongers
#    Napoleon       7.744186 Scientific conquerors
#   Bottom 3:
#   Leader  Victory drive               Cluster
#   Gandhi       1.744186    Cultural pacifists
#   Harald       2.744186 Aggressive warmongers
# Hiawatha       2.744186    Balanced diplomats
#
# =======================================================
# Loyalty
# =======================================================
#   Top 3:
#  Leader  Loyalty               Cluster
#   Shaka 7.534884 Aggressive warmongers
# Casimir 6.534884    Balanced diplomats
#  Darius 6.534884       Wonder builders
#   Bottom 3:
#        Leader  Loyalty               Cluster
# EnricoDandolo 2.534884       Wonder builders
#      Napoleon 2.534884 Scientific conquerors
#   OdaNobunaga 2.534884 Scientific conquerors
#
# =======================================================
# City-state competition
# =======================================================
#   Top 3:
#    Leader  City-state competition               Cluster
#  Augustus                7.953488 Scientific conquerors
# Elizabeth                7.953488    Balanced diplomats
#     Maria                7.953488    Balanced diplomats
#   Bottom 3:
#       Leader  City-state competition               Cluster
#    Alexander                2.953488 Scientific conquerors
# Ashurbanipal                2.953488 Aggressive warmongers
#       Attila                2.953488 Aggressive warmongers
#
# =======================================================
# Friendliness
# =======================================================
#   Top 3:
#        Leader  Friendliness            Cluster
#         Pedro      6.802326    Wonder builders
# AhmadalMansur      6.302326    Wonder builders
#       Casimir      6.302326 Balanced diplomats
#   Bottom 3:
#      Leader  Friendliness               Cluster
#       Shaka      1.802326 Aggressive warmongers
#      Attila      2.802326 Aggressive warmongers
# OdaNobunaga      2.802326 Scientific conquerors
#
# =======================================================
# Deceptiveness
# =======================================================
#   Top 3:
#  Leader  Deceptiveness               Cluster
#  Attila       7.860465 Aggressive warmongers
#    Dido       7.860465 Aggressive warmongers
# Bismark       6.860465 Scientific conquerors
#   Bottom 3:
#  Leader  Deceptiveness               Cluster
#   Shaka       1.860465 Aggressive warmongers
#   Askia       2.860465 Aggressive warmongers
# Casimir       2.860465    Balanced diplomats
#
# =======================================================
# City-state indifference
# =======================================================
#   Top 3:
#   Leader  City-state indifference               Cluster
#    Pacal                 7.604651       Wonder builders
# Boudicca                 6.604651 Aggressive warmongers
#   Harald                 6.604651 Aggressive warmongers
#   Bottom 3:
#        Leader  City-state indifference               Cluster
#         Shaka                 2.604651 Aggressive warmongers
#       Casimir                 3.604651    Balanced diplomats
# EnricoDandolo                 3.604651       Wonder builders
#
# =======================================================
# Naval focus
# =======================================================
#   Top 3:
#     Leader  Naval focus               Cluster
#     Harald     7.981395 Aggressive warmongers
# Kamehameha     7.981395    Balanced diplomats
#    William     7.981395    Balanced diplomats
#   Bottom 3:
#    Leader  Naval focus               Cluster
# Catherine     2.981395 Scientific conquerors
#    Gandhi     2.981395    Cultural pacifists
#     Pacal     2.981395       Wonder builders
#
# =======================================================
# Defensiveness
# =======================================================
#   Top 3:
#    Leader  Defensiveness            Cluster
# Pocatello       7.337209 Balanced diplomats
#  Theodora       7.337209    Wonder builders
#  Hiawatha       6.337209 Balanced diplomats
#   Bottom 3:
#       Leader  Defensiveness               Cluster
#       Attila       2.837209 Aggressive warmongers
#    Montezuma       2.837209 Aggressive warmongers
# Ashurbanipal       3.337209 Aggressive warmongers
#
# =======================================================
# Science focus
# =======================================================
#   Top 3:
#    Leader  Science focus               Cluster
# Catherine       7.744186 Scientific conquerors
#    Sejong       7.244186       Wonder builders
#  WuZetian       7.244186       Wonder builders
#   Bottom 3:
#   Leader  Science focus               Cluster
#    Shaka       2.244186 Aggressive warmongers
#   Attila       3.244186 Aggressive warmongers
# Isabella       3.244186 Aggressive warmongers
#
# =======================================================
# Expansion drive
# =======================================================
#   Top 3:
#    Leader  Expansion drive               Cluster
#     Shaka         9.744186 Aggressive warmongers
#  Hiawatha         7.744186    Balanced diplomats
# Alexander         6.744186 Scientific conquerors
#   Bottom 3:
#        Leader  Expansion drive            Cluster
# EnricoDandolo         1.744186    Wonder builders
#        Gandhi         1.744186 Cultural pacifists
# AhmadalMansur         2.744186    Wonder builders
#
# =======================================================
# City growth
# =======================================================
#   Top 3:
#    Leader  City growth            Cluster
#    Gandhi     9.883721 Cultural pacifists
# Pocatello     7.883721 Balanced diplomats
#  WuZetian     7.883721    Wonder builders
#   Bottom 3:
#     Leader  City growth               Cluster
#  Catherine     2.883721 Scientific conquerors
#   Hiawatha     2.883721    Balanced diplomats
# Kamehameha     2.883721    Balanced diplomats
#
# =======================================================
# Wonder priority
# =======================================================
#   Top 3:
#         Leader  Wonder priority         Cluster
#       Ramesses         9.860465 Wonder builders
# Nebuchadnezzar         6.860465 Wonder builders
#          Pacal         6.860465 Wonder builders
#   Bottom 3:
#      Leader  Wonder priority               Cluster
#       Askia         2.860465 Aggressive warmongers
#        Dido         2.860465 Aggressive warmongers
# GenghisKhan         2.860465 Aggressive warmongers
#
# =======================================================
# Cultural focus
# =======================================================
#   Top 3:
#       Leader  Cultural focus               Cluster
#       Gandhi        7.139535    Cultural pacifists
#     Napoleon        7.139535 Scientific conquerors
# Ramkhamhaeng        7.139535    Cultural pacifists
#   Bottom 3:
#       Leader  Cultural focus               Cluster
#        Shaka        2.139535 Aggressive warmongers
#         Dido        3.139535 Aggressive warmongers
# Ashurbanipal        4.139535 Aggressive warmongers
#
# =======================================================
# Religious focus
# =======================================================
#   Top 3:
#        Leader  Religious focus               Cluster
#      Boudicca         7.348837 Aggressive warmongers
#        Gandhi         7.348837    Cultural pacifists
# HarunAlRashid         7.348837       Wonder builders
#   Bottom 3:
#   Leader  Religious focus               Cluster
#  Bismark         2.348837 Scientific conquerors
# Napoleon         2.348837 Scientific conquerors
#    Shaka         2.348837 Aggressive warmongers
#
# =======================================================
# Diplomacy focus
# =======================================================
#   Top 3:
#    Leader  Diplomacy focus               Cluster
# Alexander         8.465116 Scientific conquerors
#  Gustavus         7.465116    Balanced diplomats
#     Maria         7.465116    Balanced diplomats
#   Bottom 3:
#       Leader  Diplomacy focus               Cluster
#  GenghisKhan         2.465116 Aggressive warmongers
#     WuZetian         2.465116       Wonder builders
# Ashurbanipal         3.465116 Aggressive warmongers

# %% [markdown]
# Radar chart

# %%
labels = list(RADAR_FEATURES.keys())
cols   = list(RADAR_FEATURES.values())
N      = len(labels)

cluster_profiles = (features
                    .drop(columns=["leader_name", "cluster_name"])
                    .groupby("cluster")
                    .mean(numeric_only=True)[cols])

y_min = cluster_profiles.min().min() 
y_max = cluster_profiles.max().max()

angles = np.linspace(0, 2 * np.pi, N, endpoint=False).tolist()
angles += angles[:1]

fig, axes = plt.subplots(2, 3, figsize=(18, 12), subplot_kw=dict(polar=True))
axes = axes.flatten()

for idx, (cluster_id, label) in enumerate(CLUSTER_LABELS.items()):
    ax = axes[idx]
    values = cluster_profiles.loc[cluster_id, cols].tolist()
    values += values[:1]

    ax.plot(angles, values, color=CLUSTER_COLORS[cluster_id], linewidth=2)
    ax.fill(angles, values, color=CLUSTER_COLORS[cluster_id], alpha=0.25)
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(labels, size=8)
    ax.set_ylim(y_min, y_max)
    ax.set_yticks(np.arange(round(y_min), round(y_max) + 1, 1))
    ax.set_title(label, size=12, fontweight="bold", pad=15)
    ax.grid(True)

axes[-1].set_visible(False)
fig.suptitle("Civ 5 leader clusters — feature profiles (scaled to cluster min/max)",
             fontsize=15, y=1.02)
plt.tight_layout()
plt.savefig("../figures/radar_clusters.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# Heatmap

# %%
col_order   = list(RADAR_FEATURES.values())
label_order = list(RADAR_FEATURES.keys())

cluster_profiles = (features
                    .drop(columns=["leader_name", "cluster_name"])
                    .groupby("cluster")
                    .mean(numeric_only=True)
                    .round(2))

cluster_profiles_readable = (cluster_profiles[col_order]
                              .rename(columns=dict(zip(col_order, label_order)),
                                      index=CLUSTER_LABELS))

plt.figure(figsize=(14, 5))
sns.heatmap(cluster_profiles_readable,
            annot=True, fmt=".1f",
            cmap="RdYlGn",
            center=5,
            vmin=3, vmax=8,
            linewidths=0.5,
            annot_kws={"size": 9})
plt.title("Civ 5 leader clusters — mean feature values", fontsize=13)
plt.xticks(rotation=45, ha="right", fontsize=9)
plt.yticks(rotation=0, fontsize=9)
plt.tight_layout()
plt.savefig("../figures/heatmap_clusters.png", dpi=150, bbox_inches="tight")
plt.show()
