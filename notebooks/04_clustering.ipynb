# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
import umap

# %% [markdown]
# Settings

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 200)
sns.set_theme(style="whitegrid")

# %% [markdown]
# Load data

# %%
# Features are already mean-centered (done in notebook 03).
# No StandardScaler is applied here: all features share the same underlying
# 0–10 scale, so their variances are directly comparable. Dividing by std
# (StandardScaler) would artificially up-weight low-variance features and
# make K-means distances less meaningful. We cluster directly on the
# centered features.

features = pd.read_csv("../data/processed_traits/3_civ5_features.csv")
 
leader_names = features["leader_name"]
X = features.drop(columns=["leader_name"])
 
print(f"Dataset: {X.shape[0]} leaders x {X.shape[1]} features")
print(f"Feature means (should all be ~5.0):\n{X.mean().round(2)}")
# Out:
# Dataset: 43 leaders x 19 features
# Feature means (should all be ~5.0):
# WarmongerHate              5.0
# WonderCompetitiveness      5.0
# VictoryCompetitiveness     5.0
# Loyalty                    5.0
# MinorCivCompetitiveness    5.0
# warrior                    5.0
# friendliness               5.0
# deceptiveness              5.0
# city_state_benefactor      5.0
# minor_ignore               5.0
# naval                      5.0
# defense                    5.0
# science                    5.0
# EXPANSION                  5.0
# GROWTH                     5.0
# WONDER                     5.0
# CULTURE                    5.0
# RELIGION                   5.0
# DIPLOMACY                  5.0
# dtype: float64

# %% [markdown]
# K-means: number of clusters selection

# %%
feature_cols = [c for c in features.columns if c not in ("leader_name", "cluster")]

# To respect original weights of features (created features regroup various origianl features, like warrior averages 5 original features"
FEATURE_WEIGHTS = {
    "WarmongerHate":          1,
    "WonderCompetitiveness":  1,
    "VictoryCompetitiveness": 1,
    "Loyalty":                1,
    "MinorCivCompetitiveness":1,
    "warrior":                5,
    "friendliness":           2,
    "deceptiveness":          1,
    "city_state_benefactor":  4,
    "minor_ignore":           1,
    "naval":                  5,
    "defense":                2,
    "science":                2,
    "EXPANSION":              1,
    "GROWTH":                 1,
    "WONDER":                 1,
    "CULTURE":                1,
    "RELIGION":               1,
    "DIPLOMACY":              1,
}

weights = np.array([FEATURE_WEIGHTS[c] for c in feature_cols])
X = pd.DataFrame(
    features[feature_cols].values * weights,
    columns=feature_cols,
    index=features.index
)

# %%
inertias = []
silhouettes = []
k_range = range(2, 11)
 
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(X)
    inertias.append(kmeans.inertia_)
    silhouettes.append(silhouette_score(X, labels))
 
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
 
axes[0].plot(k_range, inertias, marker="o")
axes[0].set_xlabel("Number of clusters (k)")
axes[0].set_ylabel("Inertia")
axes[0].set_title("Elbow curve")
 
axes[1].plot(k_range, silhouettes, marker="o", color="orange")
axes[1].set_xlabel("Number of clusters (k)")
axes[1].set_ylabel("Silhouette score")
axes[1].set_title("Silhouette score")
 
plt.tight_layout()
plt.savefig("../figures/4_kmeans_selection.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# K-means: fit k=5

# %%
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
features["cluster"] = kmeans.fit_predict(X)
 
for cluster_id in sorted(features["cluster"].unique()):
    leaders = features[features["cluster"] == cluster_id]["leader_name"].tolist()
    print(f"\nCluster {cluster_id} ({len(leaders)} leaders):")
    print(", ".join(sorted(leaders)))
# Out:
# Cluster 0 (8 leaders):
# Gandhi, HarunAlRashid, Hiawatha, Maria, Pacal, Pocatello, Ramkhamhaeng, Selassie
#
# Cluster 1 (10 leaders):
# Alexander, Ashurbanipal, Askia, Attila, Boudicca, GenghisKhan, Montezuma, Napoleon, OdaNobunaga, Shaka
#
# Cluster 2 (7 leaders):
# AhmadalMansur, Darius, EnricoDandolo, MariaI, Pedro, Sejong, Theodora
#
# Cluster 3 (10 leaders):
# Augustus, Bismark, Casimir, Catherine, Gustavus, Nebuchadnezzar, Pachacuti, Ramesses, Washington, WuZetian
#
# Cluster 4 (8 leaders):
# Dido, Elizabeth, GajahMada, Harald, Isabella, Kamehameha, Suleiman, William

# %% [markdown]
# Cluster profiles

# %%
cluster_profiles = (features
                    .drop(columns=["leader_name"])
                    .groupby("cluster")
                    .mean()
                    .round(2))
print(cluster_profiles.T)
# Out:
# cluster                     0     1     2     3     4
# WarmongerHate            6.38  3.38  5.03  5.28  5.26
# WonderCompetitiveness    5.03  4.91  4.91  6.01  3.91
# VictoryCompetitiveness   3.37  6.54  5.32  4.84  4.62
# Loyalty                  5.66  4.53  5.11  4.63  5.28
# MinorCivCompetitiveness  4.33  4.35  5.24  5.65  5.45
# warrior                  3.70  6.72  3.69  5.10  5.18
# friendliness             5.68  3.55  6.30  5.30  4.61
# deceptiveness            4.24  4.86  5.29  5.26  5.36
# city_state_benefactor    5.97  3.75  5.45  5.20  4.94
# minor_ignore             5.10  4.70  4.75  4.90  5.60
# naval                    3.33  4.88  5.35  4.24  7.46
# defense                  5.90  3.79  5.69  5.34  4.59
# science                  5.18  4.64  4.74  5.89  4.37
# EXPANSION                4.24  6.14  3.46  4.94  5.74
# GROWTH                   5.88  4.48  5.88  4.88  4.13
# WONDER                   5.49  4.26  5.15  5.96  4.11
# CULTURE                  5.64  4.94  5.00  4.84  4.64
# RELIGION                 6.22  4.45  5.21  4.45  4.97
# DIPLOMACY                5.72  4.67  4.61  4.97  5.09

# %% [markdown]
# Save cluster assignments

# %%
features[["leader_name", "cluster"]].to_csv("../data/processed_traits/4_civ5_clusters.csv", index=False)
print("Cluster assignments saved!")
# Out:
# Cluster assignments saved!

# %% [markdown]
# Constants

# %%
CLUSTER_LABELS = {
    0: "Religious pacifists",
    1: "Aggressive conquerors",
    2: "Unreliable friends",
    3: "Wonder builders",
    4: "Naval expansionists"
}
CLUSTER_COLORS = ["#2ecc71", "#e74c3c", "#e67e22", "#3498db", "#9b59b6"]

# %% [markdown]
# PCA: fit and variance explained

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
 
print(f"Variance explained: PC1={pca.explained_variance_ratio_[0]:.1%}, PC2={pca.explained_variance_ratio_[1]:.1%}")
print(f"Total: {pca.explained_variance_ratio_.sum():.1%}")
# Out:
# Variance explained: PC1=42.6%, PC2=31.0%
# Total: 73.6%

# %% [markdown]
# PCA: loadings analysis

# %%
loadings = pd.DataFrame(
    pca.components_.T,
    index=X.columns,
    columns=["PC1", "PC2"]
)
 
print("PC1 — top contributions:")
print(loadings["PC1"].sort_values(ascending=False).round(3))
 
print("\nPC2 — signed values (sorted):")
print(loadings["PC2"].sort_values(ascending=False).round(3))
# Out:
# PC1 — top contributions:
# warrior                    0.653
# naval                      0.569
# EXPANSION                  0.098
# VictoryCompetitiveness     0.090
# deceptiveness              0.020
# minor_ignore               0.004
# MinorCivCompetitiveness   -0.000
# DIPLOMACY                 -0.026
# Loyalty                   -0.027
# WonderCompetitiveness     -0.038
# CULTURE                   -0.046
# RELIGION                  -0.061
# GROWTH                    -0.073
# WONDER                    -0.079
# science                   -0.086
# WarmongerHate             -0.099
# defense                   -0.193
# friendliness              -0.193
# city_state_benefactor     -0.346
# Name: PC1, dtype: float64
#
# PC2 — signed values (sorted):
# naval                      0.806
# city_state_benefactor      0.332
# friendliness               0.103
# defense                    0.082
# WarmongerHate              0.070
# MinorCivCompetitiveness    0.051
# minor_ignore               0.036
# DIPLOMACY                  0.027
# CULTURE                    0.014
# RELIGION                   0.011
# deceptiveness              0.009
# Loyalty                    0.009
# GROWTH                    -0.003
# WONDER                    -0.022
# science                   -0.031
# WonderCompetitiveness     -0.034
# EXPANSION                 -0.055
# VictoryCompetitiveness    -0.071
# warrior                   -0.449
# Name: PC2, dtype: float64

# %% [markdown]
# PCA: visualization

# %%
fig, ax = plt.subplots(figsize=(14, 10))
 
for cluster_id, label in CLUSTER_LABELS.items():
    mask = (features["cluster"] == cluster_id).values
    ax.scatter(X_pca[mask, 0], X_pca[mask, 1],
               c=CLUSTER_COLORS[cluster_id], label=label, s=100, alpha=0.8)
    names = features[features["cluster"] == cluster_id]["leader_name"].values
    for i, name in enumerate(names):
        ax.annotate(name, (X_pca[mask, 0][i], X_pca[mask, 1][i]),
                    fontsize=7, ha="left", va="bottom")
 
ax.set_xlabel(f"PC1 — Warmongering ({pca.explained_variance_ratio_[0]:.1%})", fontsize=11)
ax.set_ylabel(f"PC2 — Naval bias ({pca.explained_variance_ratio_[1]:.1%})", fontsize=11)
ax.set_title("Civ 5 leaders — PCA 2D (k=5 clusters)", fontsize=13)
ax.legend(fontsize=10)
plt.tight_layout()
plt.savefig("../figures/4_pca_2d_clusters.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# UMAP visualization

# %%
reducer = umap.UMAP(n_components=2, random_state=42)
X_umap = reducer.fit_transform(X)
 
fig, ax = plt.subplots(figsize=(14, 10))
 
for cluster_id, label in CLUSTER_LABELS.items():
    mask = (features["cluster"] == cluster_id).values
    ax.scatter(X_umap[mask, 0], X_umap[mask, 1],
               c=CLUSTER_COLORS[cluster_id], label=label, s=100, alpha=0.8)
    names = features[features["cluster"] == cluster_id]["leader_name"].values
    for i, name in enumerate(names):
        ax.annotate(name, (X_umap[mask, 0][i], X_umap[mask, 1][i]),
                    fontsize=7, ha="left", va="bottom")
 
ax.set_xlabel("UMAP 1", fontsize=11)
ax.set_ylabel("UMAP 2", fontsize=11)
ax.set_title("Civ 5 leaders — UMAP (k=5 clusters)", fontsize=13)
ax.legend(fontsize=10)
plt.tight_layout()
plt.savefig("../figures/4_umap_clusters.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# /Users/arthurperonne/Documents/Perso_Arthur/code_perso/civ5_clustering/.venv/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# DBSCAN comparison

# %%
dbscan = DBSCAN(eps=4.0, min_samples=3)
labels_dbscan = dbscan.fit_predict(X)
 
noise_leaders = features[labels_dbscan == -1]["leader_name"].tolist()
print(f"DBSCAN outliers at eps=4.0 ({len(noise_leaders)} leaders):")
print(sorted(noise_leaders))
print("\nConclusion: DBSCAN finds no meaningful cluster structure in this dataset.")
print("K-means with k=5 is the appropriate algorithm here.")
# Out:
# DBSCAN outliers at eps=4.0 (43 leaders):
# ['AhmadalMansur', 'Alexander', 'Ashurbanipal', 'Askia', 'Attila', 'Augustus', 'Bismark', 'Boudicca', 'Casimir', 'Catherine', 'Darius', 'Dido', 'Elizabeth', 'EnricoDandolo', 'GajahMada', 'Gandhi', 'GenghisKhan', 'Gustavus', 'Harald', 'HarunAlRashid', 'Hiawatha', 'Isabella', 'Kamehameha', 'Maria', 'MariaI', 'Montezuma', 'Napoleon', 'Nebuchadnezzar', 'OdaNobunaga', 'Pacal', 'Pachacuti', 'Pedro', 'Pocatello', 'Ramesses', 'Ramkhamhaeng', 'Sejong', 'Selassie', 'Shaka', 'Suleiman', 'Theodora', 'Washington', 'William', 'WuZetian']
#
# Conclusion: DBSCAN finds no meaningful cluster structure in this dataset.
# K-means with k=5 is the appropriate algorithm here.

# %% [markdown]
# Borderline cases

# %%
# ── Maria I (In Cluster 2 (Unreliable friends), border Cluster 4 (Naval expansionists) ───────────────────────────────
#
# Maria I has indeed a rather high Naval feature (6.18, higher than the 5.35 average for 
# the unreliable friends, but still lower than 7.46 for the naval expansionists. 
# And what brings her in the unreliable friends cluster is her high friendliness (6.30, 
# equal to the average for this cluster and much higher than the 4.61 for the naval 
# expansionists) and her rather average wonder competitiveness (4.91) while the naval
# expansionists tend to be un-competitive for this part of the game (3.91).

comparison_poc = pd.concat([
    features[features["leader_name"] == "MariaI"]
        .set_index("leader_name")
        .drop(columns=["cluster"]),
    cluster_profiles.loc[[2, 4]].rename(
        index={2: "Cluster 2 (Unreliable friends)",
               4: "Cluster 4 (Naval expansionists)"})
], axis=0).T
 
print(comparison_poc.round(2))
# Out:
#                          MariaI  Cluster 2 (Unreliable friends)  Cluster 4 (Naval expansionists)
# WarmongerHate              4.88                            5.03                             5.26
# WonderCompetitiveness      4.91                            4.91                             3.91
# VictoryCompetitiveness     4.74                            5.32                             4.62
# Loyalty                    4.53                            5.11                             5.28
# MinorCivCompetitiveness    5.95                            5.24                             5.45
# warrior                    3.78                            3.69                             5.18
# friendliness               6.30                            6.30                             4.61
# deceptiveness              5.86                            5.29                             5.36
# city_state_benefactor      6.38                            5.45                             4.94
# minor_ignore               3.60                            4.75                             5.60
# naval                      6.18                            5.35                             7.46
# defense                    4.34                            5.69                             4.59
# science                    4.24                            4.74                             4.37
# EXPANSION                  5.74                            3.46                             5.74
# GROWTH                     3.88                            5.88                             4.13
# WONDER                     3.86                            5.15                             4.11
# CULTURE                    4.14                            5.00                             4.64
# RELIGION                   4.35                            5.21                             4.97
# DIPLOMACY                  4.47                            4.61                             5.09

# %%
# ── Darius (In Cluster 2 (Unreliable friends), border Cluster 3 (Wonder builders) ───────────────────────────────
#
# Darius is close to the wonder builders, thanks to its rather high wonder building 
# priority (5.86, closer to the 5.96 for wonder builders than the 5.15 for unreliable friends).
# He is however surprisingly chill when someone builds the wonder he aimed (his wonder competitiveness 
# is only 3.91, far from 6.01 for the wonder builders) and quite friendly (6.30). He is then correcly placed.

comparison_poc = pd.concat([
    features[features["leader_name"] == "Darius"]
        .set_index("leader_name")
        .drop(columns=["cluster"]),
    cluster_profiles.loc[[2, 3]].rename(
        index={2: "Cluster 2 (Unreliable friends)",
               3: "Cluster 3 (Wonder builders)"})
], axis=0).T
 
print(comparison_poc.round(2))
# Out:
#                          Darius  Cluster 2 (Unreliable friends)  Cluster 3 (Wonder builders)
# WarmongerHate              4.88                            5.03                         5.28
# WonderCompetitiveness      3.91                            4.91                         6.01
# VictoryCompetitiveness     6.74                            5.32                         4.84
# Loyalty                    6.53                            5.11                         4.63
# MinorCivCompetitiveness    3.95                            5.24                         5.65
# warrior                    3.18                            3.69                         5.10
# friendliness               6.30                            6.30                         5.30
# deceptiveness              4.86                            5.29                         5.26
# city_state_benefactor      3.88                            5.45                         5.20
# minor_ignore               5.60                            4.75                         4.90
# naval                      4.58                            5.35                         4.24
# defense                    5.84                            5.69                         5.34
# science                    5.24                            4.74                         5.89
# EXPANSION                  3.74                            3.46                         4.94
# GROWTH                     5.88                            5.88                         4.88
# WONDER                     5.86                            5.15                         5.96
# CULTURE                    4.14                            5.00                         4.84
# RELIGION                   5.35                            5.21                         4.45
# DIPLOMACY                  4.47                            4.61                         4.97

# %%
# ── Pacal (In Cluster 0 (Religious pacifists), border Cluster 3 (Wonder builders) ───────────────────────────────
#
# Pacal is extremely interested in wonders (6.86 for wonder building and 6.91 for wonder competitiveness). 
# However, unlike the other wonder builders, he is quite a loyal pacifist (3.98 warrior score, 5.53 loyalty)
# and much interested in religion (7.35!). He happens to be a religious pacifist also interested in building
# wonders.

comparison_poc = pd.concat([
    features[features["leader_name"] == "Pacal"]
        .set_index("leader_name")
        .drop(columns=["cluster"]),
    cluster_profiles.loc[[0, 3]].rename(
        index={0: "Cluster 0 (Religious pacifists)",
               3: "Cluster 3 (Wonder builders)"})
], axis=0).T
 
print(comparison_poc.round(2))
# Out:
#                          Pacal  Cluster 0 (Religious pacifists)  Cluster 3 (Wonder builders)
# WarmongerHate             5.88                             6.38                         5.28
# WonderCompetitiveness     6.91                             5.03                         6.01
# VictoryCompetitiveness    4.74                             3.37                         4.84
# Loyalty                   5.53                             5.66                         4.63
# MinorCivCompetitiveness   3.95                             4.33                         5.65
# warrior                   3.98                             3.70                         5.10
# friendliness              5.30                             5.68                         5.30
# deceptiveness             4.86                             4.24                         5.26
# city_state_benefactor     4.13                             5.97                         5.20
# minor_ignore              7.60                             5.10                         4.90
# naval                     2.98                             3.33                         4.24
# defense                   5.34                             5.90                         5.34
# science                   6.24                             5.18                         5.89
# EXPANSION                 2.74                             4.24                         4.94
# GROWTH                    4.88                             5.88                         4.88
# WONDER                    6.86                             5.49                         5.96
# CULTURE                   5.14                             5.64                         4.84
# RELIGION                  7.35                             6.22                         4.45
# DIPLOMACY                 4.47                             5.72                         4.97
